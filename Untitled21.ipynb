# %%
import random
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
class Card:
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        return self.rank + ' of ' + self.suit

# %%
class Deck:
    def __init__(self):
        
        self.allcards = []
        
        for suit in suits:
            for rank in ranks:
                created_card = Card(suit,rank)
                self.allcards.append(created_card)
    def shuffle(self):
        random.shuffle(self.allcards)
    def deal_one(self):
        return self.allcards.pop()

# %%
class Player:
    def __init__(self,name):
        self.name = name
        self.all_cards = []
        
    def remove_one(self):
        return self.all_cards.pop(0)
    
    def add_cards(self,new_cards):
        if type(new_cards) == type([]):
            self.all_cards.extend(new_cards)
        else :
            self.all_cards.append(new_cards)
    
    def __str__(self):
        return f'Player {self.name} has {len(self.all_cards)} cards'

# %%
type(one)
# Out:
# __main__.Player

# %%
one = Player('mayank')
two = Player('shubham')

new_deck = Deck()
new_deck.shuffle()


for x in range(26):
    one.add_cards(new_deck.deal_one())
    two.add_cards(new_deck.deal_one())

# %%
game_on = True
while_condition = False

# %%
round_num = 0

while game_on == True:
    round_num += 1
    print (f'Round {round_num}')
    
    if len(one.all_cards) == 0:
        print ('Player One is out of cards! Victory belongs to Two! ')
        game_on = False
        break
    if len(two.all_cards) == 0:
        print ('Player Two is out of cards! Victory belongs to One! ')
        game_on = False
        break
    else :
        pass
    
    one_cards = []
    one_cards.append(one.remove_one())
    war_cards_one = []
    
    two_cards = []
    two_cards.append(two.remove_one())
    war_cards_two = []
    
    while_condition = False
    
    if one_cards[-1].value > two_cards[-1].value:
        one.all_cards.append(one_cards.pop())
        one.all_cards.append(two_cards.pop())
    elif one_cards[-1].value < two_cards[-1].value:
        two.all_cards.append(one_cards.pop())
        two.all_cards.append(two_cards.pop())
    else :
        while_condition = True
        
    while while_condition == True:
        print('WAR STARTED!')
        if len(one.all_cards) < 6:
            print('Player One loses (no more cards left)! Player two wins!')
            game_on = False
            break
        elif len(two.all_cards) < 6:
            print('Player Two loses (no more cards left)! Player One wins!')
            game_on = False
            break
        else :
            pass
        
        war_cards_one.append(one.remove_one())
        war_cards_one.append(one.remove_one())
        war_cards_one.append(one.remove_one())
        war_cards_one.append(one.remove_one())
        war_cards_one.append(one.remove_one())
        
        
        war_cards_two.append(two.remove_one())
        war_cards_two.append(two.remove_one())
        war_cards_two.append(two.remove_one())
        war_cards_two.append(two.remove_one())
        war_cards_two.append(two.remove_one())
        
        one_cards.append(one.remove_one())
        
        two_cards.append(two.remove_one())
        
        
        if one_cards[-1].value > two_cards[-1].value:
            one.all_cards.append(one_cards.pop())
            one.all_cards.extend(war_cards_one)
            one.all_cards.append(two_cards.pop())
            one.all_cards.extend(war_cards_two)
            
            war_cards_one.clear()
            war_cards_two.clear()
            
            
            break
        elif one_cards[-1].value < two_cards[-1].value:
            two.all_cards.append(one_cards.pop())
            two.all_cards.extend(war_cards_one)
            two.all_cards.append(two_cards.pop())
            two.all_cards.extend(war_cards_two)
            
            war_cards_one.clear()
            war_cards_two.clear()
            
            break
        elif one_cards[-1].value == two_cards[-1].value:
            print('war extended')
            continue
        
        else :
            while_condition = False
            break
# Out:
# Round 1
# Round 2
# Round 3
# Round 4
# Round 5
# Round 6
# Round 7
# Round 8
# Round 9
# Round 10
# Round 11
# Round 12
# Round 13
# Round 14
# Round 15
# Round 16
# Round 17
# Round 18
# Round 19
# Round 20
# Round 21
# WAR STARTED!
# war extended
# WAR STARTED!
# Round 22
# Round 23
# Round 24
# Round 25
# Round 26
# Round 27
# Round 28
# WAR STARTED!
# Round 29
# Round 30
# Round 31
# WAR STARTED!
# Round 32
# Round 33
# Round 34
# Round 35
# Round 36
# Round 37
# WAR STARTED!
# Round 38
# WAR STARTED!
# Round 39
# Round 40
# Round 41
# WAR STARTED!
# Round 42
# Round 43
# Round 44
# Round 45
# Round 46
# Round 47
# Round 48
# Round 49
# Round 50
# Round 51
# Round 52
# Round 53
# Round 54
# Round 55
# Round 56
# Round 57
# Round 58
# Round 59
# Round 60
# Round 61
# Round 62
# Round 63
# Round 64
# Round 65
# Round 66
# Round 67
# Round 68
# Round 69
# Round 70
# Round 71
# Round 72
# Round 73
# Round 74
# Round 75
# Round 76
# Round 77
# Round 78
# Round 79
# Round 80
# ...

# %%
a = False

# %%
a = False

# %%
a
# Out:
# False
